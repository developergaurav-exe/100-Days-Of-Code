# %% [markdown]
# ### Higher or Lower (Project)

# %% [markdown]
# ###### This one is glitchy

# %%
import art, random, replit
from game_data import data
print(art.hl)


score = int()
def play():
    global score
    restart = True
    while restart:
        replit.clear()
        a = random.randint(0,49)
        b = random.randint(0,49)
        print(f"Compare A: {data[a]['name']}, a {data[a]['description']}, from {data[a]['country']}.")
        print(art.vs)
        print(f"Compare B: {data[b]['name']}, a {data[b]['description']}, from {data[b]['country']}.")
        choice = input("Who has more followers? Type 'a' or 'b': ")

        if data[a]['follower_count'] > data[b]['follower_count'] and choice.lower() == 'a':
            score += 1
            print(f"You're Right! {choice.upper()}: {data[a]['name']} has more Followers. Your Score: {score}")
            play()
        elif data[a]['follower_count'] < data[b]['follower_count'] and choice.lower() == 'a':
            print(f"You Lose! {data[a]['name']} has more Followers: {data[a]['follower_count']}M.")
            restart = False
            break

        elif data[a]['follower_count'] < data[b]['follower_count'] and choice.lower() == 'b':
            score += 1
            print(f"You're Right! {choice.upper()}: {data[b]['name']} has more Followers. Your Score: {score}")
            play()
        else:
            print(f"You Lose! {data[a]['name']} has more Followers: {data[a]['follower_count']}M.")
            restart = False  
            break

play()
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Compare A: NBA, a Club Basketball Competition, from United States.
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Compare B: Miley Cyrus, a Musician and actress, from United States.
# You're Right! B: Miley Cyrus has more Followers. Your Score: 1
# Compare A: Taylor Swift, a Musician, from United States.
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Compare B: Lionel Messi, a Footballer, from Argentina.
# You're Right! B: Lionel Messi has more Followers. Your Score: 2
# Compare A: NBA, a Club Basketball Competition, from United States.
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Compare B: Kendall Jenner, a Reality TV personality and Model, from United States.
# You Lose! NBA has more Followers: 47M.
# Compare A: UEFA Champions League, a Club football competition, from Europe.
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Compare B: Khloé Kardashian, a Reality TV personality and businesswoman, from United States.
# You Lose! UEFA Champions League has more Followers: 58M.
# Compare A: Cardi B, a Musician, from United States.
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Compare B: Shawn Mendes, a Musician, from Canada.
# You Lose! Cardi B has more Followers: 67M.

# %% [markdown]
# #### Solution by Angela

# %%
from game_data import data
import random
from art import hl, vs
from replit import clear

def get_random_account():
  """Get data from random account"""
  return random.choice(data)

def format_data(account):
  """Format account into printable format: name, description and country"""
  name = account["name"]
  description = account["description"]
  country = account["country"]
  # print(f'{name}: {account["follower_count"]}')
  return f"{name}, a {description}, from {country}"

def check_answer(guess, a_followers, b_followers):
  """Checks followers against user's guess 
  and returns True if they got it right.
  Or False if they got it wrong.""" 
  if a_followers > b_followers:
    return guess == "a"
  else:
    return guess == "b"


def game():
  print(hl)
  score = 0
  game_should_continue = True
  account_a = get_random_account()
  account_b = get_random_account()

  while game_should_continue:
    account_a = account_b
    account_b = get_random_account()

    while account_a == account_b:
      account_b = get_random_account()

    print(f"Compare A: {format_data(account_a)}.")
    print(vs)
    print(f"Against B: {format_data(account_b)}.")
    
    guess = input("Who has more followers? Type 'A' or 'B': ").lower()
    a_follower_count = account_a["follower_count"]
    b_follower_count = account_b["follower_count"]
    is_correct = check_answer(guess, a_follower_count, b_follower_count)

    clear()
    print(hl)
    if is_correct:
      score += 1
      print(f"You're right! Current score: {score}.")
    else:
      game_should_continue = False
      print(f"Sorry, that's wrong. Final score: {score}")

game()
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Compare A: Ronaldinho, a Footballer, from Brasil.
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Camila Cabello, a Musician, from Cuba.
#
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# You're right! Current score: 1.
# Compare A: Camila Cabello, a Musician, from Cuba.
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Dwayne Johnson, a Actor and professional wrestler, from United States.
#
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Sorry, that's wrong. Final score: 1

# %%
'''

FAQ: Why does choice B always become choice A in every round, even when A had more followers? 

Suppose you just started the game and you are comparing the followers of A - Instagram (364k) to B - Selena Gomez (174k). Instagram has more followers, so choice A is correct. However, the subsequent comparison should be between Selena Gomez (the new A) and someone else. The reason is that everything in our list has fewer followers than Instagram. If we were to keep Instagram as part of the comparison (as choice A) then Instagram would stay there for the rest of the game. This would be quite boring. By swapping choice B for A each round, we avoid a situation where the number of followers of choice A keeps going up over the course of the game. Hope that makes sense :-)

'''



# Generate a random account from the game data.

# Format account data into printable format.

# Ask user for a guess.

# Check if user is correct.
## Get follower count.
## If Statement

# Feedback.

# Score Keeping.

# Make game repeatable.

# Make B become the next A.

# Add art.

# Clear screen between rounds.
# Out:
# '\n\nFAQ: Why does choice B always become choice A in every round, even when A had more followers? \n\nSuppose you just started the game and you are comparing the followers of A - Instagram (364k) to B - Selena Gomez (174k). Instagram has more followers, so choice A is correct. However, the subsequent comparison should be between Selena Gomez (the new A) and someone else. The reason is that everything in our list has fewer followers than Instagram. If we were to keep Instagram as part of the comparison (as choice A) then Instagram would stay there for the rest of the game. This would be quite boring. By swapping choice B for A each round, we avoid a situation where the number of followers of choice A keeps going up over the course of the game. Hope that makes sense :-)\n\n'
